# %%
About Dataset

In 2021, 537 million adults (20-79 years) had diabetes, which is 1 in 10 people. We all know that Diabetes is a 
Leading Cause of Blindness Worldwide. Adults with Diabetes Are Twice as Likely to Die from Heart Disease or Stroke.
Many Early Symptoms of Diabetes Are Too Mild to Notice. Half of All Those with Diabetes Are Undiagnosed.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/akhilmandula/Desktop/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
corr_df = df.corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data=corr_df,annot=True,cmap ='Blues')
plt.show()

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
df['Insulin'].unique()
# Out:
# array([  0,  94, 168,  88, 543, 846, 175, 230,  83,  96, 235, 146, 115,
#        140, 110, 245,  54, 192, 207,  70, 240,  82,  36,  23, 300, 342,
#        304, 142, 128,  38, 100,  90, 270,  71, 125, 176,  48,  64, 228,
#         76, 220,  40, 152,  18, 135, 495,  37,  51,  99, 145, 225,  49,
#         50,  92, 325,  63, 284, 119, 204, 155, 485,  53, 114, 105, 285,
#        156,  78, 130,  55,  58, 160, 210, 318,  44, 190, 280,  87, 271,
#        129, 120, 478,  56,  32, 744, 370,  45, 194, 680, 402, 258, 375,
#        150,  67,  57, 116, 278, 122, 545,  75,  74, 182, 360, 215, 184,
#         42, 132, 148, 180, 205,  85, 231,  29,  68,  52, 255, 171,  73,
#        108,  43, 167, 249, 293,  66, 465,  89, 158,  84,  72,  59,  81,
#        196, 415, 275, 165, 579, 310,  61, 474, 170, 277,  60,  14,  95,
#        237, 191, 328, 250, 480, 265, 193,  79,  86, 326, 188, 106,  65,
#        166, 274,  77, 126, 330, 600, 185,  25,  41, 272, 321, 144,  15,
# ...

# %%
df['Age'].unique()
# Out:
# array([50, 31, 32, 21, 33, 30, 26, 29, 53, 54, 34, 57, 59, 51, 27, 41, 43,
#        22, 38, 60, 28, 45, 35, 46, 56, 37, 48, 40, 25, 24, 58, 42, 44, 39,
#        36, 23, 61, 69, 62, 55, 65, 47, 52, 66, 49, 63, 67, 72, 81, 64, 70,
#        68])

# %%
df['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190])

# %%
df['BMI'].unique()
# Out:
# array([33.6, 26.6, 23.3, 28.1, 43.1, 25.6, 31. , 35.3, 30.5,  0. , 37.6,
#        38. , 27.1, 30.1, 25.8, 30. , 45.8, 29.6, 43.3, 34.6, 39.3, 35.4,
#        39.8, 29. , 36.6, 31.1, 39.4, 23.2, 22.2, 34.1, 36. , 31.6, 24.8,
#        19.9, 27.6, 24. , 33.2, 32.9, 38.2, 37.1, 34. , 40.2, 22.7, 45.4,
#        27.4, 42. , 29.7, 28. , 39.1, 19.4, 24.2, 24.4, 33.7, 34.7, 23. ,
#        37.7, 46.8, 40.5, 41.5, 25. , 25.4, 32.8, 32.5, 42.7, 19.6, 28.9,
#        28.6, 43.4, 35.1, 32. , 24.7, 32.6, 43.2, 22.4, 29.3, 24.6, 48.8,
#        32.4, 38.5, 26.5, 19.1, 46.7, 23.8, 33.9, 20.4, 28.7, 49.7, 39. ,
#        26.1, 22.5, 39.6, 29.5, 34.3, 37.4, 33.3, 31.2, 28.2, 53.2, 34.2,
#        26.8, 55. , 42.9, 34.5, 27.9, 38.3, 21.1, 33.8, 30.8, 36.9, 39.5,
#        27.3, 21.9, 40.6, 47.9, 50. , 25.2, 40.9, 37.2, 44.2, 29.9, 31.9,
#        28.4, 43.5, 32.7, 67.1, 45. , 34.9, 27.7, 35.9, 22.6, 33.1, 30.4,
#        52.3, 24.3, 22.9, 34.8, 30.9, 40.1, 23.9, 37.5, 35.5, 42.8, 42.6,
# ...

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14])

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
sns.catplot(x='Outcome',kind='count',data=df)
plt.title('Distribution of diabetes in the dataset')
plt.show()

# %%
plt.title('Diabetes in each age group') 
plt.figure(figsize=(15,8))
sns.countplot(data=df, x='Age',hue='Outcome')
plt.show()

# %%
X= df.drop(columns = ['Outcome'])
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y= df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=11)

# %%
X_train.count()
# Out:
# Pregnancies                 614
# Glucose                     614
# BloodPressure               614
# SkinThickness               614
# Insulin                     614
# BMI                         614
# DiabetesPedigreeFunction    614
# Age                         614
# dtype: int64

# %%
y_train.count()
# Out:
# 614

# %%
X_train.shape
# Out:
# (614, 8)

# %% [markdown]
# Scaling of Features is an essential step in modeling the algorithms with the datasets.
#
# The data obtained contains features of various dimensions and scales altogether. Different scales of the data
# features affect the modeling of a dataset adversely.
#
# It leads to a biased outcome of predictions in terms of misclassification error and accuracy rates. Thus, it is
# necessary  to scale the data prior to modeling.
#
# This is when standardization comes into picture.
#
# Standardization is a scaling technique wherein it makes the data scale-free by converting the statistical
# distribution of the data into the below format:
#
# mean - 0 (zero)
# standard deviation - 1
#
# Z= (X-Mean)/SD

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
Further, we use fit_transform() along with the assigned object to transform the data and standardize it.

# %%
X_train_trf = sc.fit_transform(X_train)
X_test_trf = sc.fit_transform(X_test)
X_train_trf
# Out:
# array([[ 2.63944429, -0.47498577,  0.03145909, ...,  0.26499528,
#         -0.66103011,  1.60686985],
#        [-0.85640786, -1.30859939,  0.29108114, ..., -0.01489808,
#         -0.22750148, -0.96646893],
#        [ 0.30887619,  0.2660041 ,  0.654552  , ...,  0.88839413,
#          1.44681595,  0.32020046],
#        ...,
#        [ 0.01755518,  0.04988205,  0.55070318, ..., -0.01489808,
#         -0.08697841,  0.06286658],
#        [-0.27376584, -0.25886373, -1.31857556, ..., -1.23625094,
#         -0.99290374, -0.96646893],
#        [-0.56508685,  0.23512952, -3.60324957, ...,  0.81205958,
#         -0.50256792,  0.6633123 ]])

# %%
X_train_trf[0]
# Out:
# array([ 2.63944429, -0.47498577,  0.03145909, -1.30243134, -0.68020125,
#         0.26499528, -0.66103011,  1.60686985])

# %%
X_train_trf.shape
# Out:
# (614, 8)

# %% [markdown]
# # Principal Component Analysis (2 dimensions)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)

i = pca.fit_transform(X_train,y_train)
i
principal_df = pd.DataFrame(data=i,columns= ['PC1','PC2'])
principal_df
# Out:
# array([[-79.48065225,   3.19476202],
#        [-80.38619824,  34.86826612],
#        [-76.72627054, -19.61317739],
#        ...,
#        [ 98.03341635,   6.80156022],
#        [-78.38813902,   5.14784038],
#        [-77.90511876,  -9.08781628]])

# %% [markdown]
# # Clustering - FInd the optimal number of clusters - Elbow method
#
# Plot Sum of Squared Errors (SSE)against K value

# %%
from sklearn.cluster import KMeans

SSE = []

K= range(2,9)

for i in K:
    kmeanModel = KMeans(n_clusters=i)
    kmeanModel.fit(principal_df)
    SSE.append(kmeanModel.inertia_)

# %%
plt.figure()
plt.plot(K,SSE)

plt.ylabel('Inertia(SSE)')
plt.xlabel('Number of clusters(K)')
plt.show()

# %% [markdown]
# We use K=3 ; K Means

# %%
kmeans = KMeans(n_clusters = 3).fit(principal_df)
plt.scatter(principal_df['PC1'],principal_df['PC2'],c=kmeans.labels_)
plt.title('Diabetes 2D K-Means')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(linestyle='dotted')
plt.show()
